# %%
import pandas as pd
import numpy as np

# df_gov = pd.read_excel('../GovData/HIST_PAINEL_COVIDBR_Mod.xlsx', index_col=None)

df_gov = pd.read_excel('HIST_PAINEL_COVIDBR_20200515.xlsx', index_col=None)

df_gov
# Out:
#        regiao estado municipio  coduf  codmun  codRegiaoSaude nomeRegiaoSaude  \
# 0      Brasil    NaN       NaN     76     NaN             NaN             NaN
# 1      Brasil    NaN       NaN     76     NaN             NaN             NaN
# 2      Brasil    NaN       NaN     76     NaN             NaN             NaN
# 3      Brasil    NaN       NaN     76     NaN             NaN             NaN
# 4      Brasil    NaN       NaN     76     NaN             NaN             NaN
# ...       ...    ...       ...    ...     ...             ...             ...
# 78994     Sul     RS       NaN     43     NaN             NaN             NaN
# 78995     Sul     RS       NaN     43     NaN             NaN             NaN
# 78996     Sul     RS       NaN     43     NaN             NaN             NaN
# 78997     Sul     RS       NaN     43     NaN             NaN             NaN
# 78998     Sul     RS       NaN     43     NaN             NaN             NaN
#
#              data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 0      2020-02-26          9       210147125.0               1
# 1      2020-02-27          9       210147125.0               1
# 2      2020-02-28          9       210147125.0               1
# 3      2020-02-29          9       210147125.0               2
# 4      2020-03-01         10       210147125.0               2
# ...           ...        ...               ...             ...
# 78994  2020-05-11         20        11377239.0            2576
# 78995  2020-05-12         20        11377239.0            2917
# 78996  2020-05-13         20        11377239.0            2917
# 78997  2020-05-14         20        11377239.0            2997
# 78998  2020-05-15         20        11377239.0            3597
#
#        obitosAcumulado  Recuperadosnovos  emAcompanhamentoNovos
# 0                    0               NaN                    NaN
# 1                    0               NaN                    NaN
# 2                    0               NaN                    NaN
# 3                    0               NaN                    NaN
# 4                    0               NaN                    NaN
# ...                ...               ...                    ...
# 78994              105               NaN                    NaN
# 78995              111               NaN                    NaN
# 78996              111               NaN                    NaN
# 78997              120               NaN                    NaN
# 78998              126               NaN                    NaN
#
# [78999 rows x 14 columns]

# %%
city_name = 'Brasília'

df_city = df_gov.loc[df_gov['municipio'] == city_name]

df_city['dias'] = np.arange(len(df_city))

df_city.head()
# Out:
# <ipython-input-3-8a794a1ee459>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['dias'] = np.arange(len(df_city))
#             regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 4658  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4659  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4660  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4661  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4662  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 4658        Brasília  2020-03-28         13         3015268.0             260
# 4659        Brasília  2020-03-29         14         3015268.0             289
# 4660        Brasília  2020-03-30         14         3015268.0             312
# 4661        Brasília  2020-03-31         14         3015268.0             332
# 4662        Brasília  2020-04-01         14         3015268.0             355
#
#       obitosAcumulado  Recuperadosnovos  emAcompanhamentoNovos  dias
# 4658                0               NaN                    NaN     0
# 4659                1               NaN                    NaN     1
# 4660                1               NaN                    NaN     2
# 4661                3               NaN                    NaN     3
# 4662                3               NaN                    NaN     4

# %%
df_city.plot(x='dias', y='casosAcumulado');

# %%
df_city.plot(x='dias', y='obitosAcumulado');

# %%
df_city.head()
# Out:
#             regiao estado municipio  coduf    codmun  codRegiaoSaude  \
# 4658  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4659  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4660  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4661  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
# 4662  Centro-Oeste     DF  Brasília     53  530010.0         53001.0
#
#      nomeRegiaoSaude        data  semanaEpi  populacaoTCU2019  casosAcumulado  \
# 4658        Brasília  2020-03-28         13         3015268.0             260
# 4659        Brasília  2020-03-29         14         3015268.0             289
# 4660        Brasília  2020-03-30         14         3015268.0             312
# 4661        Brasília  2020-03-31         14         3015268.0             332
# 4662        Brasília  2020-04-01         14         3015268.0             355
#
#       obitosAcumulado  Recuperadosnovos  emAcompanhamentoNovos  dias
# 4658                0               NaN                    NaN     0
# 4659                1               NaN                    NaN     1
# 4660                1               NaN                    NaN     2
# 4661                3               NaN                    NaN     3
# 4662                3               NaN                    NaN     4

# %%
cummCases = df_city['casosAcumulado'].to_numpy()
print(cummCases)

cummDeaths = df_city['obitosAcumulado'].to_numpy()
print(cummDeaths)
# Out:
# [ 260  289  312  332  355  370  402  454  468  473  492  509  527  555
#   579  614  638  651  682  716  746  762  827  872  881  946  963  989
#  1013 1066 1146 1213 1275 1356 1466 1566 1649 1768 1818 1906 2258 2442
#  2576 2682 2783 2979 3192 3416 3787]
# [ 0  1  1  3  3  4  5  7  7 10 12 12 13 14 14 14 15 17 17 20 20 24 24 24
#  24 25 25 26 26 27 27 28 28 30 30 31 33 33 33 34 35 37 39 42 44 46 48 51
#  55]

# %%
len(cummCases)
# Out:
# 49

# %%
len(cummDeaths)
city_pop = df_city['populacaoTCU2019'].iloc[0]
print(city_pop)
# Out:
# 3015268.0

# %% [markdown]
# ## Clean the code for generalization

# %%
import pandas as pd
import numpy as np

# Reading the data from https://covid.saude.gov.br/
# df_gov = pd.read_excel('../GovData/HIST_PAINEL_COVIDBR_Mod.xlsx', index_col=None)
df_gov = pd.read_excel('HIST_PAINEL_COVIDBR_20200515.xlsx', index_col=None)

# Chosing city
city_name = 'Brasília'

df_city = df_gov.loc[df_gov['municipio'] == city_name]

# Adding days since first notice column
df_city['dias'] = np.arange(len(df_city))

# Saving Cummulative cases and deaths to np.array
cummCases = df_city['casosAcumulado'].to_numpy()
print(cummCases)

cummDeaths = df_city['obitosAcumulado'].to_numpy()
print(cummDeaths)
# Out:
# [ 260  289  312  332  355  370  402  454  468  473  492  509  527  555
#   579  614  638  651  682  716  746  762  827  872  881  946  963  989
#  1013 1066 1146 1213 1275 1356 1466 1566 1649 1768 1818 1906 2258 2442
#  2576 2682 2783 2979 3192 3416 3787]
# [ 0  1  1  3  3  4  5  7  7 10 12 12 13 14 14 14 15 17 17 20 20 24 24 24
#  24 25 25 26 26 27 27 28 28 30 30 31 33 33 33 34 35 37 39 42 44 46 48 51
#  55]
# <ipython-input-10-76249dd5cfea>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_city['dias'] = np.arange(len(df_city))
